# %% [markdown]
# TITANIC ANALYSIS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# # 2 Print Starting 10 rows and last 10 rows

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %% [markdown]
# # 3 shape of the data

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# # 4 print all columns name

# %%
df.columns.tolist()
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %% [markdown]
# # 5 find the datatype of each columns

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # 6 print information and summery

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # 7 count survived and show on pie chart

# %%
var1 = df.Survived.value_counts()

# %%
import matplotlib.pyplot as plt

# %%
var1
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
plt.pie(var1, shadow = True, autopct="%0.2f%%", 
        labels =["Not-Survived","Survived"], colors = ['r','g'])
plt.title('Survived and Not-Survived Passengers')
plt.show()

# %% [markdown]
# # 8 Find out how many female passengers had travelled in first class and show on pie chart

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.Sex.value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df_female = df[df.Sex == 'female']

# %%
var2 = df_female.Pclass.value_counts()
var2
# Out:
# Pclass
# 3    144
# 1     94
# 2     76
# Name: count, dtype: int64

# %%
plt.pie(var2, colors = ['#c85d96', '#467fc8', "#c8466b"], 
        labels=['3rd','1st','2nd'], autopct='%0.02f%%', shadow=True, explode=(0,0.1,0))
plt.title('Female Passengers travel in different classes')
plt.show()

# %% [markdown]
# # 9 Find out how many female passengers had Survived and her age <30, show on pie chart and bar graph

# %%
df_female[df_female.Age<30]
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 14            15         0       3
# ..           ...       ...     ...
# 874          875         1       2
# 875          876         1       3
# 880          881         1       2
# 882          883         0       3
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# ..                                                 ...     ...   ...    ...
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 882                       Dahlberg, Miss. Gerda Ulrika  female  22.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 8        2            347742  11.1333   NaN        S
# 9        0            237736  30.0708   NaN        C
# 10       1           PP 9549  16.7000    G6        S
# 14       0            350406   7.8542   NaN        S
# ..     ...               ...      ...   ...      ...
# 874      0         P/PP 3381  24.0000   NaN        C
# 875      0              2667   7.2250   NaN        C
# 880      1            230433  26.0000   NaN        S
# 882      0              7552  10.5167   NaN        S
# 887      0            112053  30.0000   B42        S
#
# [147 rows x 12 columns]

# %%
df_f_a=df[(df.Age<30) & (df.Sex =='female')]
var3 = df_f_a.Survived.value_counts()
var3
# Out:
# Survived
# 1    105
# 0     42
# Name: count, dtype: int64

# %%
plt.pie(var3, shadow = True, autopct="%0.2f%%", 
        labels =["Survived","Not-Survived"], colors = ['g','r'],explode=(0.1,0))
plt.title('Female with her age < 30')
plt.show()

# %% [markdown]
# # 10 Find out how many male passengers had Survived and his age >40, show on pie chart

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.Sex.value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df_male = df[df.Sex == 'male']

# %%
df_male
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    22.0      1      0         A/5 21171   7.2500   NaN        S
# 4    35.0      0      0            373450   8.0500   NaN        S
# 5     NaN      0      0            330877   8.4583   NaN        Q
# 6    54.0      0      0             17463  51.8625   E46        S
# 7     2.0      3      1            349909  21.0750   NaN        S
# ..    ...    ...    ...               ...      ...   ...      ...
# 883  28.0      0      0  C.A./SOTON 34068  10.5000   NaN        S
# 884  25.0      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 886  27.0      0      0            211536  13.0000   NaN        S
# 889  26.0      0      0            111369  30.0000  C148        C
# 890  32.0      0      0            370376   7.7500   NaN        Q
#
# [577 rows x 12 columns]

# %%
var4 = df_male.Pclass.value_counts()
var4
# Out:
# Pclass
# 3    347
# 1    122
# 2    108
# Name: count, dtype: int64

# %%
df_male[df_male.Age>40]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 33            34         0       2           Wheadon, Mr. Edward H  male
# 35            36         0       1  Holverson, Mr. Alexander Oskar  male
# 54            55         0       1  Ostby, Mr. Engelhart Cornelius  male
# 62            63         0       1     Harris, Mr. Henry Birkhardt  male
# ..           ...       ...     ...                             ...   ...
# 845          846         0       3             Abbing, Mr. Anthony  male
# 851          852         0       3             Svensson, Mr. Johan  male
# 857          858         1       1          Daly, Mr. Peter Denis   male
# 860          861         0       3         Hansen, Mr. Claus Peter  male
# 873          874         0       3     Vander Cruyssen, Mr. Victor  male
#
#       Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 6    54.0      0      0       17463  51.8625   E46        S
# 33   66.0      0      0  C.A. 24579  10.5000   NaN        S
# 35   42.0      1      0      113789  52.0000   NaN        S
# 54   65.0      0      1      113509  61.9792   B30        C
# 62   45.0      1      0       36973  83.4750   C83        S
# ..    ...    ...    ...         ...      ...   ...      ...
# 845  42.0      0      0   C.A. 5547   7.5500   NaN        S
# 851  74.0      0      0      347060   7.7750   NaN        S
# 857  51.0      0      0      113055  26.5500   E17        S
# 860  41.0      2      0      350026  14.1083   NaN        S
# 873  47.0      0      0      345765   9.0000   NaN        S
#
# [102 rows x 12 columns]

# %%
df_m_a=df[(df.Age>40) & (df.Sex =='male')]
var4 = df_m_a.Survived.value_counts()
var4
# Out:
# Survived
# 0    84
# 1    18
# Name: count, dtype: int64

# %%
plt.pie(var4, shadow = True, autopct="%0.2f%%", 
        labels =["Not-Survived","Survived"], colors = ['r','g'],explode=(0,0.1))
plt.title('male with his age > 40')
plt.show()

# %% [markdown]
# # 11  Show age with 20 bins

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.Age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
import numpy as np

# %%
counts, bins, _ = plt.hist(df.Age, bins= 20, color = 'purple', edgecolor = 'black', label='Age Bins')
bin_centers = (bins[:-1]+ bins[1:])/2
plt.plot(bin_centers, counts, marker= 'o', color='r', label= 'Age Distribution')
plt.xticks(np.arange(0,84,4))
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# # 12 Show age frequency with survived and not survived (Histogram)

# %%
var5 = df[df.Survived ==1].Age
counts, bins, _ = plt.hist(var5, bins= 20, color = 'purple', edgecolor = 'black', label='Age Bins')
bin_centers = (bins[:-1]+ bins[1:])/2
plt.plot(bin_centers, counts, marker= 'o', color='r', label= 'Age Distribution')
plt.xticks(np.arange(0,84,4))
plt.title('Survived Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
var6 = df[df.Survived ==0].Age
counts, bins, _ = plt.hist(var6, bins= 20, color = 'purple', edgecolor = 'black', label='Age Bins')
bin_centers = (bins[:-1]+ bins[1:])/2
plt.plot(bin_centers, counts, marker= 'o', color='r', label= 'Age Distribution')
plt.xticks(np.arange(0,84,4))
plt.title('Not-Survived Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# # 13 Show Bar graph for Survived with male, female, class

# %%
s_df=df[df.Survived == 1]

# %%
s_df.Sex.value_counts()
# Out:
# Sex
# female    233
# male      109
# Name: count, dtype: int64

# %%
s_df.Pclass.value_counts()
# Out:
# Pclass
# 1    136
# 3    119
# 2     87
# Name: count, dtype: int64

# %%
import seaborn as sns

# %%
pip install mkl numpy seaborn
# Out:
# Requirement already satisfied: mkl in c:\users\tingu\appdata\local\programs\python\python313\lib\site-packages (2025.0.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy in c:\users\tingu\appdata\local\programs\python\python313\lib\site-packages (2.2.3)
# Requirement already satisfied: seaborn in c:\users\tingu\appdata\local\programs\python\python313\lib\site-packages (0.13.2)
# Requirement already satisfied: intel-openmp>=2024 in c:\users\tingu\appdata\local\programs\python\python313\lib\site-packages (from mkl) (2025.0.5)
# Requirement already satisfied: tbb==2022.* in c:\users\tingu\appdata\local\programs\python\python313\lib\site-packages (from mkl) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in c:\users\tingu\appdata\local\programs\python\python313\lib\site-packages (from tbb==2022.*->mkl) (1.2.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\tingu\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\tingu\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (3.10.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2025.0.5 in c:\users\tingu\appdata\local\programs\python\python313\lib\site-packages (from intel-openmp>=2024->mkl) (2025.0.5)
# Requirement already satisfied: umf==0.9.* in c:\users\tingu\appdata\local\programs\python\python313\lib\site-packages (from intel-cmplr-lib-ur==2025.0.5->intel-openmp>=2024->mkl) (0.9.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\tingu\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\tingu\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tingu\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\tingu\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\tingu\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\tingu\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\tingu\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tingu\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tingu\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tingu\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\tingu\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
sns.countplot(x = "Pclass", hue='Sex',data= s_df)

# %% [markdown]
# # 14 How many passengers are travelled in different classes show in Bar graph

# %%
temp = df.Pclass.value_counts()
temp

# %%
value = list(temp)
value

# %%
data = dict(temp)
x = data.keys()
count = data.values()
count

# %%
import matplotlib.pyplot as plt

# %%
val = []
for i in x:
    if  i==1:
        val.append("1st Class")
    elif i==2:
        val.append("2nd Class")
    elif i==3:
        val.append("3rd Class")

# %%
val

# %%
plt.bar(x,count, color=["red","green","blue"])
plt.title("Passenger Class")
plt.xlabel("Classes")
plt.ylabel("Count of Passengers")
plt.grid()
plt.show()

# %% [markdown]
# # 15  How many passengers are survived with class wise and show in Bar graph

# %%
sns.countplot(x = "Pclass", hue = "Survived",data =df)

# %% [markdown]
# # 16  Show Question-13 & Question-14 in subplot

# %%
fig, axs = plt.subplots(1,2, figsize=(10, 3))
sns.countplot(x = "Pclass", hue = "Sex", data = s_df, ax = axs[0])
axs[0].set_title("Survived passenger for gender and class")

axs[1].bar(val, count, color=["red", "green", "blue"])
axs[1].set_title("Passenger Class")
axs[1].set_xlabel("Classes")
axs[1].set_ylabel("Count of passengers")
axs[1].grid()

plt.show()

# %% [markdown]
# # 17 Show Bar graph for Survived with 3rd class male, 1st class female

# %%
df[(df.Pclass==3) & (df.Sex=='male')].Survived.value_counts()

# %%
df[(df.Pclass==3) & (df.Sex=='male')].Survived.value_counts().plot(kind = "bar", color=["red","green"])

# %%
df[(df.Pclass==1) & (df.Sex=='female')].Survived.value_counts().plot(kind = "bar", color=["green","red"])

# %% [markdown]
# # 18  How many passengers are survived / not survived and they are 1st class female

# %%
df[(df.Pclass==1) & (df.Sex=='female')].Survived.value_counts()

# %%
pd.crosstab(df["Pclass"], df["Sex"])

# %%
pd.crosstab(df["Pclass"], df["Sex"], margins= True)

# %% [markdown]
# # Subplot

# %%
fig, axs = plt.subplots(2,2, figsize= (10,8))
var1 = df[(df.Pclass==3) & (df.Sex=='male')].Survived.value_counts()
var1.plot(kind = "bar", color=["red","green"], ax =axs[0][0])
axs[0][0].set_title("3rd class Male Passengers")

var1 = df[(df.Pclass==1) & (df.Sex=='female')].Survived.value_counts()
var1.plot(kind = "bar", color=["g","r"], ax =axs[0][1])
axs[0][1].set_title("1st class Female Passengers")

sns.countplot(x = "Pclass", hue = "Sex",data =df[df.Survived==1], ax=axs[1,0])
axs[0][0].set_title("Passenger Classes along with Sex")

var4 = df[(df.Sex =='male')& (df.Age>40)].Survived.value_counts()
axs[1][1].pie(var4, shadow = True, autopct="%0.2f%%", 
        labels =["Not-Survived","Survived"], colors = ['r','g'],explode=(0,0.1))
axs[1][1].set_title('male with his age > 40')

plt.show()

# %% [markdown]
# # 19  Map the Sex column male=1, female =0

# %%
df.head()

# %%
df.describe()

# %%
df[["Survived", "Pclass", "Age"]].corr()

# %%
df.Sex = df.Sex.map({'male':1, 'female':0})

# %%
df

# %% [markdown]
# ### Label Encoder

# %%
pip install scikit-learn

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df["Embarked"] = le.fit_transform(df["Embarked"])

# %%
df

# %%
df.Embarked.unique()

# %%
le.fit_transform(df["Embarked"])

# %% [markdown]
# # 20  Find Null values

# %%
df = pd.read_csv('Titanic.csv')

# %%
df.isnull().sum()

# %% [markdown]
# # 21  Replace Null value to Median value

# %%
df.Age.isnull().sum()

# %%
df[df.Age.isnull()]

# %%
df.Age.describe()

# %%
df['Age']=df.Age.fillna(28)

# %%
df['Age']

# %% [markdown]
# # 22 Drop unwanted columns

# %%
df.head()

# %%
cols = ["Survived","Pclass","Sex","Age","SibSp","Parch","Fare","Embarked"]

# %%
Final_df = df[cols]

# %%
Final_df.Sex = df.Sex = df.Sex.map({'male':1, 'female':0})

# %%
Final_df
